# %% [markdown]
# #  Choosing an ODE Algorithm
#
# While the default algorithms, along with `alg_hints = [:stiff]`, will suffice in most cases, there are times when you may need to exert more control. The purpose of this part of the tutorial is to introduce you to some of the most widely used algorithm choices and when they should be used. The corresponding page of the documentation is the [ODE Solvers](http://docs.juliadiffeq.org/latest/solvers/ode_solve.html) page which goes into more depth.

# %% [markdown]
# ## Diagnosing Stiffness
#
# One of the key things to know for algorithm choices is whether your problem is stiff. Let's take for example the driven Van Der Pol equation:

# %%
using DifferentialEquations
van! = @ode_def VanDerPol begin
  dy = μ*((1-x^2)*y - x)
  dx = 1*y
end μ

prob = ODEProblem(van!,[0.0,2.0],(0.0,6.3),1e6)
# Out:
# DiffEqBase.ODEProblem with uType Array{Float64,1} and tType Float64. In-place: true
# timespan: (0.0, 6.3)
# u0: [0.0, 2.0]

# %% [markdown]
# One indicating factor that should alert you to the fact that this model may be stiff is the fact that the parameter is `1e6`: large parameters generally mean stiff models. If we try to solve this with the default method:

# %%
sol = solve(prob)
# Out:
# WARNING: Interrupted. Larger maxiters is needed.
# retcode: MaxIters
# Interpolation: specialized 4th order "free" interpolation
# t: 999978-element Array{Float64,1}:
#  0.0
#  4.9975e-10
#  5.49725e-9
#  3.28991e-8
#  9.05558e-8
#  1.73095e-7
#  2.79375e-7
#  4.14953e-7
#  5.80791e-7
#  7.8128e-7
#  1.01968e-6
#  1.30218e-6
#  1.6366e-6
#  ⋮
#  1.84586
#  1.84586
#  1.84586
#  1.84586
#  1.84586
#  1.84586
#  1.84587
#  1.84587
#  1.84587
#  1.84587
#  1.84587
#  1.84587
# u: 999978-element Array{Array{Float64,1},1}:
#  [0.0, 2.0]
#  [-0.000998751, 2.0]
#  [-0.0109043, 2.0]
#  [-0.0626554, 2.0]
#  [-0.158595, 2.0]
#  [-0.270036, 2.0]
#  [-0.37832, 2.0]
#  [-0.474679, 2.0]
#  [-0.54993, 2.0]
#  [-0.602693, 2.0]
#  [-0.635376, 2.0]
#  [-0.653257, 2.0]
#  [-0.661747, 2.0]
#  ⋮
#  [-0.777544, 1.83159]
#  [-0.777545, 1.83159]
#  [-0.777546, 1.83159]
#  [-0.777547, 1.83159]
#  [-0.777548, 1.83159]
#  [-0.777549, 1.83159]
#  [-0.77755, 1.83159]
#  [-0.777551, 1.83159]
#  [-0.777552, 1.83158]
#  [-0.777553, 1.83158]
#  [-0.777553, 1.83158]
#  [-0.777554, 1.83158]

# %% [markdown]
# Here it shows that maximum iterations were reached. Another thing that can happen is that the solution can return that the solver was unstable (exploded to infinity) or that `dt` became too small. If these happen, the first thing to do is to check that your model is correct. It could very well be that you made an error that causes the model to be unstable!
#
# If the model is the problem, then stiffness could be the reason. We can thus hint to the solver to use an appropriate method:

# %%
sol = solve(prob,alg_hints = [:stiff])
# Out:
# retcode: Success
# Interpolation: specialized 3rd order "free" stiffness-aware interpolation
# t: 730-element Array{Float64,1}:
#  0.0
#  4.9975e-10
#  5.45414e-9
#  1.89543e-8
#  4.14966e-8
#  7.30807e-8
#  1.17146e-7
#  1.74812e-7
#  2.48623e-7
#  3.40254e-7
#  4.52108e-7
#  5.86677e-7
#  7.47363e-7
#  ⋮
#  5.65145
#  5.66158
#  5.69681
#  5.74799
#  5.81057
#  5.88543
#  5.96795
#  6.05487
#  6.14133
#  6.22312
#  6.29638
#  6.3
# u: 730-element Array{Array{Float64,1},1}:
#  [0.0, 2.0]
#  [-0.000998751, 2.0]
#  [-0.0108195, 2.0]
#  [-0.0368509, 2.0]
#  [-0.0780351, 2.0]
#  [-0.131248, 2.0]
#  [-0.19755, 2.0]
#  [-0.272074, 2.0]
#  [-0.350452, 2.0]
#  [-0.426453, 2.0]
#  [-0.494929, 2.0]
#  [-0.551972, 2.0]
#  [-0.59584, 2.0]
#  ⋮
#  [0.667157, -1.99912]
#  [0.670953, -1.99234]
#  [0.684721, -1.96846]
#  [0.706461, -1.93287]
#  [0.736368, -1.88775]
#  [0.778221, -1.8311]
#  [0.834755, -1.76464]
#  [0.911736, -1.68889]
#  [1.01723, -1.60577]
#  [1.16577, -1.51693]
#  [1.38442, -1.42423]
#  [1.39944, -1.4192]

# %% [markdown]
# Another way to understand stiffness is to look at the solution.

# %%
using Plots; gr()
sol = solve(prob,alg_hints = [:stiff],reltol=1e-6)
plot(sol,denseplot=false)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 68.7969,360.065 580.315,360.065 580.315,11.811 68.7969,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0702">
#     <rect x="68" y="11" width="513" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.7969,360.065 68.7969,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.99,360.065 149.99,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   231.184,360.065 231.184,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   312.377,360.065 312.377,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   393.57,360.065 393.57,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.764,360.065 474.764,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   555.957,360.065 555.957,11.811
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.7969,316.519 580.315,316.519
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.7969,251.229 580.315,251.229
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.7969,185.94 580.315,185.94
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.7969,120.65 580.315,120.65
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.7969,55.3605 580.315,55.3605
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,360.065 68.7969,11.811
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,360.065 68.7969,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.99,360.065 149.99,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   231.184,360.065 231.184,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   312.377,360.065 312.377,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   393.57,360.065 393.57,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.764,360.065 474.764,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   555.957,360.065 555.957,354.842
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,316.519 76.4697,316.519
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,251.229 76.4697,251.229
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,185.94 76.4697,185.94
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,120.65 76.4697,120.65
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.7969,55.3605 76.4697,55.3605
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 68.7969, 373.865)" x="68.7969" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.99, 373.865)" x="149.99" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 231.184, 373.865)" x="231.184" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 312.377, 373.865)" x="312.377" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 393.57, 373.865)" x="393.57" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 474.764, 373.865)" x="474.764" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 555.957, 373.865)" x="555.957" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.7969, 321.019)" x="62.7969" y="321.019">-1000000</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.7969, 255.729)" x="62.7969" y="255.729">-500000</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.7969, 190.44)" x="62.7969" y="190.44">0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.7969, 125.15)" x="62.7969" y="125.15">500000</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 62.7969, 59.8605)" x="62.7969" y="59.8605">1000000</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 324.556, 397.6)" x="324.556" y="397.6">t</text>
# </g>
# <polyline clip-path="url(#clip0702)" style="stroke:#009af9;

# %% [markdown]
# Let's zoom in on the y-axis to see what's going on:

# %%
plot(sol,ylims = (-10.0,10.0))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0900)" points="
# 35.8488,360.065 580.315,360.065 580.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0902">
#     <rect x="35" y="11" width="545" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,360.065 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   122.272,360.065 122.272,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   208.695,360.065 208.695,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   295.118,360.065 295.118,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   381.542,360.065 381.542,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   467.965,360.065 467.965,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   554.388,360.065 554.388,11.811
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,273.002 580.315,273.002
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,185.938 580.315,185.938
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,98.8746 580.315,98.8746
#   "/>
# <polyline clip-path="url(#clip0902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8488,11.811 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 35.8488,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   122.272,360.065 122.272,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   208.695,360.065 208.695,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   295.118,360.065 295.118,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   381.542,360.065 381.542,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   467.965,360.065 467.965,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   554.388,360.065 554.388,354.842
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,360.065 44.0158,360.065
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,273.002 44.0158,273.002
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,185.938 44.0158,185.938
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,98.8746 44.0158,98.8746
#   "/>
# <polyline clip-path="url(#clip0900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,11.811 44.0158,11.811
#   "/>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 35.8488, 373.865)" x="35.8488" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 122.272, 373.865)" x="122.272" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 208.695, 373.865)" x="208.695" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 295.118, 373.865)" x="295.118" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 381.542, 373.865)" x="381.542" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 467.965, 373.865)" x="467.965" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 554.388, 373.865)" x="554.388" y="373.865">6</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 364.565)" x="29.8488" y="364.565">-10</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 277.502)" x="29.8488" y="277.502">-5</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 190.438)" x="29.8488" y="190.438">0</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 103.375)" x="29.8488" y="103.375">5</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 16.311)" x="29.8488" y="16.311">10</text>
# </g>
# <g clip-path="url(#clip0900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 308.082, 397.6)" x="308.082" y="397.6">t</text>
# </g>
# <polyline clip-path="url(#clip0902)" style="stroke:#009af9; st

# %% [markdown]
# Notice how there are some extreme vertical shifts that occur. These vertical shifts are places where the derivative term is very large, and this is indicative of stiffness. This is an extreme example to highlight the behavior, but this general idea can be carried over to your problem. When in doubt, simply try timing using both a stiff solver and a non-stiff solver and see which is more efficient.
#
# To try this out, let's use BenchmarkTools, a package that let's us relatively reliably time code blocks.

# %%
using BenchmarkTools

# %% [markdown]
# Let's compare the performance of non-stiff and stiff solvers on the Lorenz equation, which we saw in the last notebook, "ODEIntroduction".
#
# First, let's grab all our information about the Lorenz equation from the last notebook.

# %%
function lorenz!(du,u,p,t)
    σ,ρ,β = p
    du[1] = σ*(u[2]-u[1])
    du[2] = u[1]*(ρ-u[3]) - u[2]
    du[3] = u[1]*u[2] - β*u[3]    
end
u0 = [1.0,0.0,0.0]
p = (10,28,8/3)
tspan = (0.0,100.0)
prob = ODEProblem(lorenz!,u0,tspan,p)
# Out:
# DiffEqBase.ODEProblem with uType Array{Float64,1} and tType Float64. In-place: true
# timespan: (0.0, 100.0)
# u0: [1.0, 0.0, 0.0]

# %% [markdown]
# And now, let's use the `@btime` macro from benchmark tools to compare the use of non-stiff and stiff solvers on this problem.

# %%
@btime solve(prob);
# Out:
#   1.136 ms (13385 allocations: 1.40 MiB)

# %%
@btime solve(prob,alg_hints = [:stiff]);
# Out:
#   8.222 ms (57126 allocations: 2.57 MiB)

# %% [markdown]
# In this particular case, we can see that non-stiff solvers get us to the solution much more quickly.

# %% [markdown]
# ## The Recommended Methods
#
# When picking a method, the general rules are as follows:
#
# - Higher order is more efficient at lower tolerances, lower order is more efficient at higher tolerances
# - Adaptivity is essential in most real-world scenarios
# - Runge-Kutta methods do well with non-stiff equations, Rosenbrock methods do well with small stiff equations, BDF methods do well with large stiff equations
#
# While there are always exceptions to the rule, those are good guiding principles. Based on those, a simple way to choose methods is:
#
# - The default is `Tsit5()`, a non-stiff Runge-Kutta method of Order 5
# - If you use low tolerances (`1e-8`), try `Vern7()` or `Vern9()`
# - If you use high tolerances, try `BS3()`
# - If the problem is stiff, try `Rosenbrock23()`, `Rodas4()`, or `CVODE_BDF()`
#
# (This is a simplified version of the default algorithm chooser)
#
# ## Comparison to other Software
#
# If you are familiar with MATLAB, SciPy, or R's DESolve, here's a quick translation start to have transfer your knowledge over.
#
# - ode23 –> BS3()
# - ode45/dopri5 –> DP5(), though in most cases Tsit5() is more efficient
# - ode23s –> Rosenbrock23(), though in most cases Rodas4() is more efficient
# - ode113 –> CVODE_Adams(), though in many cases Vern7() is more efficient
# - dop853 –> DP8(), though in most cases Vern7() is more efficient
# - ode15s/vode –> CVODE_BDF(), though in many cases Rodas4() or radau() are more efficient
# - ode23t –> Trapezoid() for efficiency and GenericTrapezoid() for robustness
# - ode23tb –> TRBDF2
# - lsoda –> lsoda() (requires Pkg.add("LSODA"); using LSODA)
# - ode15i –> IDA(), though in many cases Rodas4() can handle the DAE and is significantly more efficient
