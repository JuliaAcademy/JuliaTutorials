# %% [markdown]
# # Introduction to DataFrames
# **[Bogumił Kamiński](http://bogumilkaminski.pl/about/), May 23, 2018**
#
# Let's get started by loading the `DataFrames` package.

# %%
using DataFrames

# %% [markdown]
# ## Constructors and conversion

# %% [markdown]
# ### Constructors
#
# In this section, you'll see many ways to create a `DataFrame` using the `DataFrame()` constructor.
#
# First, we could create an empty DataFrame,

# %%
DataFrame() # empty DataFrame
# Out:
# 0×0 DataFrames.DataFrame

# %% [markdown]
# Or we could call the constructor using keyword arguments to add columns to the `DataFrame`.

# %%
DataFrame(A=1:3, B=rand(3), C=randstring.([3,3,3]))
# Out:
# 3×3 DataFrames.DataFrame
# │ Row │ A │ B        │ C   │
# ├─────┼───┼──────────┼─────┤
# │ 1   │ 1 │ 0.865057 │ Jds │
# │ 2   │ 2 │ 0.870442 │ hDG │
# │ 3   │ 3 │ 0.128666 │ oyt │

# %% [markdown]
# We can create a `DataFrame` from a dictionary, in which case keys from the dictionary will be sorted to create the `DataFrame` columns.

# %%
x = Dict("A" => [1,2], "B" => [true, false], "C" => ['a', 'b'])
DataFrame(x)
# Out:
# 2×3 DataFrames.DataFrame
# │ Row │ A │ B     │ C   │
# ├─────┼───┼───────┼─────┤
# │ 1   │ 1 │ true  │ 'a' │
# │ 2   │ 2 │ false │ 'b' │

# %% [markdown]
# Rather than explicitly creating a dictionary first, as above, we could pass `DataFrame` arguments with the syntax of dictionary key-value pairs.
#
# Note that in this case, we use symbols to denote the column names and arguments are not sorted. For example, `:A`, the symbol, produces `A`, the name of the first column here:

# %%
DataFrame(:A => [1,2], :B => [true, false], :C => ['a', 'b'])
# Out:
# 2×3 DataFrames.DataFrame
# │ Row │ A │ B     │ C   │
# ├─────┼───┼───────┼─────┤
# │ 1   │ 1 │ true  │ 'a' │
# │ 2   │ 2 │ false │ 'b' │

# %% [markdown]
# Here we create a `DataFrame` from a vector of vectors, and each vector becomes a column.

# %%
DataFrame([rand(3) for i in 1:3])
# Out:
# 3×3 DataFrames.DataFrame
# │ Row │ x1        │ x2       │ x3       │
# ├─────┼───────────┼──────────┼──────────┤
# │ 1   │ 0.738969  │ 0.476396 │ 0.926968 │
# │ 2   │ 0.498559  │ 0.190063 │ 0.839678 │
# │ 3   │ 0.0957712 │ 0.843156 │ 0.120698 │

# %% [markdown]
#  For now we can construct a single `DataFrame` from a `Vector` of atoms, creating a `DataFrame` with a single row. In future releases of DataFrames.jl, this will throw an error.

# %%
DataFrame(rand(3))
# Out:
# WARNING: passing columns argument with non-AbstractVector entries is deprecated
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] #DataFrame#57(::Bool, ::Type{T} where T, ::Array{Float64,1}, ::Array{Symbol,1}) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:154
#  [3] DataFrames.DataFrame(::Array{Float64,1}) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:152
#  [4] include_string(::String, ::String) at .\loading.jl:522
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at D:\Software\JULIA_PKG\v0.6\IJulia\src\execute_request.jl:158
#  [6] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at D:\Software\JULIA_PKG\v0.6\Compat\src\Compat.jl:385
#  [7] eventloop(::ZMQ.Socket) at D:\Software\JULIA_PKG\v0.6\IJulia\src\eventloop.jl:8
#  [8] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[7], in expression starting on line 1
# 1×3 DataFrames.DataFrame
# │ Row │ x1       │ x2     │ x3       │
# ├─────┼──────────┼────────┼──────────┤
# │ 1   │ 0.613673 │ 0.9388 │ 0.976714 │

# %% [markdown]
# Instead use a transposed vector if you have a vector of atoms (in this way you effectively pass a two dimensional array to the constructor which is supported).

# %%
DataFrame(transpose([1, 2, 3]))
# Out:
# 1×3 DataFrames.DataFrame
# │ Row │ x1 │ x2 │ x3 │
# ├─────┼────┼────┼────┤
# │ 1   │ 1  │ 2  │ 3  │

# %% [markdown]
# Pass a second argument to give the columns names.

# %%
DataFrame([1:3, 4:6, 7:9], [:A, :B, :C])
# Out:
# 3×3 DataFrames.DataFrame
# │ Row │ A │ B │ C │
# ├─────┼───┼───┼───┤
# │ 1   │ 1 │ 4 │ 7 │
# │ 2   │ 2 │ 5 │ 8 │
# │ 3   │ 3 │ 6 │ 9 │

# %% [markdown]
# Here we create a `DataFrame` from a matrix,

# %%
DataFrame(rand(3,4))
# Out:
# 3×4 DataFrames.DataFrame
# │ Row │ x1       │ x2       │ x3       │ x4        │
# ├─────┼──────────┼──────────┼──────────┼───────────┤
# │ 1   │ 0.874557 │ 0.777246 │ 0.949467 │ 0.697868  │
# │ 2   │ 0.579164 │ 0.816029 │ 0.191466 │ 0.0563065 │
# │ 3   │ 0.280777 │ 0.795716 │ 0.201309 │ 0.191633  │

# %% [markdown]
# and here we do the same but also pass column names.

# %%
DataFrame(rand(3,4), Symbol.('a':'d'))
# Out:
# 3×4 DataFrames.DataFrame
# │ Row │ a        │ b        │ c         │ d         │
# ├─────┼──────────┼──────────┼───────────┼───────────┤
# │ 1   │ 0.627336 │ 0.850384 │ 0.225164  │ 0.617465  │
# │ 2   │ 0.645045 │ 0.709581 │ 0.0780468 │ 0.0941601 │
# │ 3   │ 0.48563  │ 0.608378 │ 0.777213  │ 0.630866  │

# %% [markdown]
# We can also construct an uninitialized DataFrame.
#
# Here we pass column types, names and number of rows; we get `missing` in column :C because `Any >: Missing`.

# %%
DataFrame([Int, Float64, Any], [:A, :B, :C], 1)
# Out:
# 1×3 DataFrames.DataFrame
# │ Row │ A         │ B            │ C       │
# ├─────┼───────────┼──────────────┼─────────┤
# │ 1   │ 147259888 │ 1.08013e-319 │ missing │

# %% [markdown]
# Here we create a `DataFrame`, but column `:C` is #undef and Jupyter has problem with displaying it. (This works OK at the REPL.)
#
# This will be fixed in next release of DataFrames!

# %%
DataFrame([Int, Float64, String], [:A, :B, :C], 1)
# Out:
# UndefRefError: access to undefined reference
#
# Stacktrace:
#  [1] getindex(::Array{String,1}, ::Int64) at .\array.jl:554
#  [2] getindex(::DataFrames.DataFrame, ::Int64, ::Symbol) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:275
#  [3] show(::IOContext{Base.AbstractIOBuffer{Array{UInt8,1}}}, ::MIME{Symbol("text/html")}, ::DataFrames.DataFrame) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\abstractdataframe\io.jl:110
#  [4] limitstringmime(::MIME{Symbol("text/html")}, ::DataFrames.DataFrame) at D:\Software\JULIA_PKG\v0.6\IJulia\src\inline.jl:24
#  [5] display_dict(::DataFrames.DataFrame) at D:\Software\JULIA_PKG\v0.6\IJulia\src\execute_request.jl:43
#  [6] (::Compat.#inner#17{Array{Any,1},IJulia.#display_dict,Tuple{DataFrames.DataFrame}})() at D:\Software\JULIA_PKG\v0.6\Compat\src\Compat.jl:385
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at D:\Software\JULIA_PKG\v0.6\IJulia\src\execute_request.jl:186
#  [8] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at D:\Software\JULIA_PKG\v0.6\Compat\src\Compat.jl:385
#  [9] eventloop(::ZMQ.Socket) at D:\Software\JULIA_PKG\v0.6\IJulia\src\eventloop.jl:8
#  [10] (::IJulia.##14#17)() at .\task.jl:335

# %% [markdown]
# To initialize a `DataFrame` with column names, but no rows use

# %%
DataFrame([Int, Float64, String], [:A, :B, :C], 0)
# Out:
# 0×3 DataFrames.DataFrame

# %% [markdown]
# This syntax gives us a quick way to create homogenous `DataFrame`.

# %%
DataFrame(Int, 3, 5)
# Out:
# 3×5 DataFrames.DataFrame
# │ Row │ x1        │ x2        │ x3            │ x4 │ x5        │
# ├─────┼───────────┼───────────┼───────────────┼────┼───────────┤
# │ 1   │ 202568848 │ 199866128 │ 1649267441664 │ 0  │ 439701264 │
# │ 2   │ 147292368 │ 147292368 │ 0             │ 0  │ 148642768 │
# │ 3   │ 147293072 │ 147292432 │ 0             │ 0  │ 439701424 │

# %% [markdown]
# This example is similar, but has nonhomogenous columns.

# %%
DataFrame([Int, Float64], 4)
# Out:
# 4×2 DataFrames.DataFrame
# │ Row │ x1        │ x2           │
# ├─────┼───────────┼──────────────┤
# │ 1   │ 148644688 │ 2.17246e-315 │
# │ 2   │ 147261328 │ 2.17242e-315 │
# │ 3   │ 147261328 │ 2.17246e-315 │
# │ 4   │ 0         │ 2.20078e-315 │

# %% [markdown]
# Finally, we can create a `DataFrame` by copying an existing `DataFrame`.
#
# Note that `copy` creates a shallow copy.

# %%
y = DataFrame(x)
z = copy(x)
(x === y), (x === z), isequal(x, z)
# Out:
# (false, false, true)

# %% [markdown]
# ### Conversion to a matrix
#
# Let's start by creating a `DataFrame` with two rows and two columns.

# %%
x = DataFrame(x=1:2, y=["A", "B"])
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ x │ y │
# ├─────┼───┼───┤
# │ 1   │ 1 │ A │
# │ 2   │ 2 │ B │

# %% [markdown]
# We can create a matrix by passing this `DataFrame` to `Matrix`.

# %%
Matrix(x)
# Out:
# 2×2 Array{Any,2}:
#  1  "A"
#  2  "B"

# %% [markdown]
# This would work even if the `DataFrame` had some `missing`s:

# %%
x = DataFrame(x=1:2, y=[missing,"B"])
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ x │ y       │
# ├─────┼───┼─────────┤
# │ 1   │ 1 │ missing │
# │ 2   │ 2 │ B       │

# %%
Matrix(x)
# Out:
# 2×2 Array{Any,2}:
#  1  missing
#  2  "B"

# %% [markdown]
# In the two previous matrix examples, Julia created matrices with elements of type `Any`. We can see more clearly that the type of matrix is inferred when we pass, for example, a `DataFrame` of integers to `Matrix`, creating a 2D `Array` of `Int64`s:

# %%
x = DataFrame(x=1:2, y=3:4)
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ x │ y │
# ├─────┼───┼───┤
# │ 1   │ 1 │ 3 │
# │ 2   │ 2 │ 4 │

# %%
Matrix(x)
# Out:
# 2×2 Array{Int64,2}:
#  1  3
#  2  4

# %% [markdown]
# In this next example, Julia correctly identifies that `Union` is needed to express the type of the resulting `Matrix` (which contains `missing`s).

# %%
x = DataFrame(x=1:2, y=[missing,4])
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ x │ y       │
# ├─────┼───┼─────────┤
# │ 1   │ 1 │ missing │
# │ 2   │ 2 │ 4       │

# %%
Matrix(x)
# Out:
# 2×2 Array{Union{Int64, Missings.Missing},2}:
#  1   missing
#  2  4

# %% [markdown]
# Note that we can't force a conversion of `missing` values to `Int`s!

# %%
Matrix{Int}(x)
# Out:
# cannot convert a DataFrame containing missing values to array (found for column y)
#
# Stacktrace:
#  [1] convert(::Type{Array{Int64,2}}, ::DataFrames.DataFrame) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\abstractdataframe\abstractdataframe.jl:626
#  [2] Array{Int64,2}(::DataFrames.DataFrame) at .\sysimg.jl:77

# %% [markdown]
# ### Handling of duplicate column names
#
# We can pass the `makeunique` keyword argument to allow passing duplicate names (they get deduplicated)

# %%
df = DataFrame(:a=>1, :a=>2, :a_1=>3; makeunique=true)
# Out:
# 1×3 DataFrames.DataFrame
# │ Row │ a │ a_2 │ a_1 │
# ├─────┼───┼─────┼─────┤
# │ 1   │ 1 │ 2   │ 3   │

# %% [markdown]
# Otherwise, duplicates will not be allowed in the future.

# %%
df = DataFrame(:a=>1, :a=>2, :a_1=>3)
# Out:
# WARNING: Duplicate variable names are deprecated: pass makeunique=true to add a suffix automatically.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] #make_unique#3(::Bool, ::Function, ::Array{Symbol,1}) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\other\utils.jl:61
#  [3] (::DataFrames.#kw##make_unique)(::Array{Any,1}, ::DataFrames.#make_unique, ::Array{Symbol,1}) at .\<missing>:0
#  [4] #Index#6 at D:\Software\JULIA_PKG\v0.6\DataFrames\src\other\index.jl:12 [inlined]
#  [5] (::Core.#kw#Type)(::Array{Any,1}, ::Type{DataFrames.Index}, ::Array{Symbol,1}) at .\<missing>:0
#  [6] #DataFrame#47(::Bool, ::Type{T} where T, ::Pair{Symbol,Int64}, ::Vararg{Pair{Symbol,Int64},N} where N) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:126
#  [7] DataFrames.DataFrame(::Pair{Symbol,Int64}, ::Pair{Symbol,Int64}, ::Pair{Symbol,Int64}) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:124
#  [8] include_string(::String, ::String) at .\loading.jl:522
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at D:\Software\JULIA_PKG\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at D:\Software\JULIA_PKG\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at D:\Software\JULIA_PKG\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[28], in expression starting on line 1
# 1×3 DataFrames.DataFrame
# │ Row │ a │ a_2 │ a_1 │
# ├─────┼───┼─────┼─────┤
# │ 1   │ 1 │ 2   │ 3   │

# %% [markdown]
# A constructor that is passed column names as keyword arguments is a corner case.
# You cannot pass `makeunique` to allow duplicates here.

# %%
df = DataFrame(a=1, a=2, makeunique=true)
# Out:
# WARNING: Duplicate variable names are deprecated: pass makeunique=true to add a suffix automatically.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] #make_unique#3(::Bool, ::Function, ::Array{Symbol,1}) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\other\utils.jl:61
#  [3] (::DataFrames.#kw##make_unique)(::Array{Any,1}, ::DataFrames.#make_unique, ::Array{Symbol,1}) at .\<missing>:0
#  [4] #Index#6 at D:\Software\JULIA_PKG\v0.6\DataFrames\src\other\index.jl:12 [inlined]
#  [5] (::Core.#kw#Type)(::Array{Any,1}, ::Type{DataFrames.Index}, ::Array{Symbol,1}) at .\<missing>:0
#  [6] #DataFrame#47(::Bool, ::Type{T} where T, ::Pair{Symbol,Int64}, ::Vararg{Pair{Symbol,#s8} where #s8,N} where N) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:126
#  [7] DataFrames.DataFrame(::Pair{Symbol,Int64}, ::Pair{Symbol,Int64}, ::Pair{Symbol,Bool}) at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:124
#  [8] #DataFrame#56 at D:\Software\JULIA_PKG\v0.6\DataFrames\src\dataframe\dataframe.jl:145 [inlined]
#  [9] (::Core.#kw#Type)(::Array{Any,1}, ::Type{DataFrames.DataFrame}) at .\<missing>:0
#  [10] include_string(::String, ::String) at .\loading.jl:522
#  [11] execute_request(::ZMQ.Socket, ::IJulia.Msg) at D:\Software\JULIA_PKG\v0.6\IJulia\src\execute_request.jl:158
#  [12] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at D:\Software\JULIA_PKG\v0.6\Compat\src\Compat.jl:385
#  [13] eventloop(::ZMQ.Socket) at D:\Software\JULIA_PKG\v0.6\IJulia\src\eventloop.jl:8
#  [14] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[29], in expression starting on line 1
# 1×3 DataFrames.DataFrame
# │ Row │ a │ a_1 │ makeunique │
# ├─────┼───┼─────┼────────────┤
# │ 1   │ 1 │ 2   │ true       │
